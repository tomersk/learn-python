# %% [markdown]
# <a href="https://colab.research.google.com/github/tomersk/learn-python/blob/main/04_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 4.8 River Routing–Muskingum method
# The outflow using Muskingum method is calculated as,
#
# $Q_{j+1} = C_1 I_{j+1} + C_2 I_j + C_3 Q_j$.
#
# We are given the value of $C_1$, $C_2$, $C_3$, and $Q_0$, and we are interested in getting the value of $Q$ from
# time ($t = 0$) to ($t = 19$). In this example, first we define variables, and then we iterate using for loop. The list $I$ is quiet long, and will not fit into one line. In such cases we can go to second line also, the beginning of brackets tells Python that list has started, and the end brackets tells Python
# that this is end of the list. We can write list in as many line as we want, no need to specify anything else to tell Python that list is defined in multi-line.

# %%
import numpy as np

# define the variables
I = np.array([93, 137, 208, 320, 442, 546, 630, 678, 691, 675, 634, 571, 477, 
              390, 329, 247, 184, 134, 108, 90])
C1 = 0.0631
C2 = 0.3442
C3 = 0.5927

Q = np.empty(20) # define the empty array
Q[0] = 85 # initial value of Q

# loop over
for i in range(1,20):
  Q[i] = C1*I[i] + C2*I[i-1] + C3*Q[i-1]

# %% [markdown]
# Now we can use *matplotlib.pyplot* to plot the inflow and outflow. "-*" means a continuous line
# with stars, and *--s* means dashed line with square.

# %%
import matplotlib.pyplot as plt

plt.plot(I, '-*', label='Inflow')
plt.plot(Q, '--s', label='Outflow')
plt.xlabel('Time', fontsize=20)
plt.ylabel('Flow', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# Above figure shows the variation of inflow and outflow with time. The outflow shows a lag with respect
# to inflow, and the peak in the outflow is slightly lesser than the inflow.
